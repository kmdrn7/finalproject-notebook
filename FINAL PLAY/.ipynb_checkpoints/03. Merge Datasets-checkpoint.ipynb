# %%
import pandas as pd
import numpy as np
from glob import glob
from sklearn import preprocessing
from imblearn.under_sampling import RandomUnderSampler

# %%
def get_csv(uri):
    csvs = []
    if "*" in uri:
        all_csv = glob(uri)
        [ csvs.append(pd.read_csv(uri)) for uri in all_csv ]
        return pd.concat(csvs)
    return pd.read_csv(uri)

# %% [markdown]
# ### Dataset

# %%
dataset = get_csv('/media/kmdr7/Seagate/FP/PREPROCESSED/Malware/Unseen*')
dataset.shape
# Out:
# (347345, 79)

# %% [markdown]
# ### Store Sampled Dataset

# %%
dataset.to_csv("/media/kmdr7/Seagate/FP/PREPROCESSED/Malware/UnseenDataset.csv", index=False)

# %%
dataset
# Out:
#      Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0         6.0       190145.0               6.0                5.0
# 1         6.0       191649.0               6.0                5.0
# 2         6.0       190649.0               4.0                5.0
# 3         6.0       190648.0               6.0                5.0
# 4         6.0       186661.0               4.0                5.0
# ..        ...            ...               ...                ...
# 284       6.0    115427667.0              25.0               24.0
# 285       6.0    115635819.0              25.0               24.0
# 286       6.0    115305277.0              25.0               24.0
# 287       6.0     15701039.0               5.0                0.0
# 288       6.0     15360244.0               5.0                0.0
#
#      Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                           0.0                        77.0
# ...

# %%
malware = get_csv('/media/kmdr7/Seagate/FP/PREPROCESSED/Malware/UnseenDataset.csv')
malware.shape
# Out:
# (347345, 79)

# %%
benign = get_csv('/media/kmdr7/Seagate/FP/PREPROCESSED/Benign/UnseenData.csv')
benign.shape
# Out:
# (266997, 79)

# %%
ds = pd.concat([malware, benign])
ds.shape
# Out:
# (614342, 79)

# %%
ds.to_csv('/media/kmdr7/Seagate/FP/PREPROCESSED/TrainingValidationDataset.csv')
