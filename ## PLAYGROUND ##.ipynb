# %%
from pycaret.classification import *
from nfstream import NFStreamer
import pandas as pd

# %%
dataset = pd.read_csv("/media/kmdr7/Seagate/TA/DATASETS/2018-12-21-15-50-14-192.168.1.195.pcap_Flow.csv")

# %%
dataset.head(1)
# Out:
#                                    Flow ID         Src IP  Src Port  \
# 0  192.168.1.195-185.244.25.235-41040-80-6  192.168.1.195     41040
#
#            Dst IP  Dst Port  Protocol               Timestamp  Flow Duration  \
# 0  185.244.25.235        80         6  21/12/2018 09:50:16 PM       33373221
#
#    Total Fwd Packet  Total Bwd packets  Total Length of Fwd Packet  \
# 0                94                 93                       149.0
#
#    Total Length of Bwd Packet  Fwd Packet Length Max  Fwd Packet Length Min  \
# 0                    132596.0                  149.0                    0.0
#
#    Fwd Packet Length Mean  Fwd Packet Length Std  Bwd Packet Length Max  \
# 0                1.585106              15.368177                 2896.0
#
#    Bwd Packet Length Min  Bwd Packet Length Mean  Bwd Packet Length Std  \
# 0                    0.0             1425.763441             268.419828
#
#    Flow Bytes/s  Flow Packets/s  Flow IAT Mean  Flow IAT Std  Flow IAT Max  \
# ...

# %%
my_streamer = NFStreamer(
    source="/media/kmdr7/Seagate/DATASETS/IOT-23/CTU-IoT-Malware-Capture-34-1/2018-12-21-15-50-14-192.168.1.195.pcap",
    statistical_analysis=True
).to_pandas()

# %%
my_streamer[["user_agent"]]
# Out:
#                        user_agent
# 0     Wget/1.18 (linux-gnueabihf)
# 1     Wget/1.18 (linux-gnueabihf)
# 2                             NaN
# 3                             NaN
# 4     Wget/1.18 (linux-gnueabihf)
# ...                           ...
# 5365                          NaN
# 5366                          NaN
# 5367                          NaN
# 5368                          NaN
# 5369                          NaN
#
# [5370 rows x 1 columns]

# %%
data = dataset.sample(frac=0.7, random_state=756)
datatest = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
datatest.reset_index(inplace=True, drop=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(datatest.shape))

# %%
exp_clf101 = setup(data=data, target='Label', session_id=123)

# %%
best_model = compare_models()
