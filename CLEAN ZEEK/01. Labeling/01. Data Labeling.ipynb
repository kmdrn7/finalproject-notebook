# %%
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('/media/kmdr7/Seagate/DATASETS/Merged-IoT-Dataset/Dataset.csv')

# %%
sns.catplot(x="label", hue="detailed-label", data=dataset, kind="count", aspect=2, legend=True)

# %%
print("Malware dataset: " + str(dataset[dataset.label == "Malicious"].shape[0]))
print("Benign dataset: " + str(dataset[dataset.label == "Benign"].shape[0]))
print("Total dataset: " + str(dataset.shape[0]))
# Out:
# Malware dataset: 181041
# Benign dataset: 195823
# Total dataset: 376864
