# %%
import ray
ray.init(address='auto', _redis_password='5241590000000000')

import modin.pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Out:
# 2021-01-24 22:33:35,107	INFO worker.py:656 -- Connecting to existing Ray cluster at address: 192.168.100.35:6379

# %%
dataset = pd.read_csv("/media/kmdr7/Seagate/DATASETS/Processed-Dataset/02-Null.csv")
dataset.shape
# Out:
# (376829, 82)

# %%
y = dataset[["label"]]

# %%
x = dataset.drop(["label", "detailed-label"], axis=1)

# %% [markdown]
# # Min-Max Normalization

# %%
scaler = MinMaxScaler()
minmax_dataset = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %% [markdown]
# # Perbandingan Sebelum dan Sesudah Normalisasi

# %% [markdown]
# ## Sebelum

# %%
plt.plot(x.max())

# %%
plt.plot(x.min())

# %% [markdown]
# ## Sesudah

# %%
plt.plot(minmax_dataset.max())

# %%
plt.plot(minmax_dataset.min())

# %%
minmax_dataset["label"] = dataset.label
minmax_dataset["detailed-label"] = dataset["detailed-label"]
minmax_dataset.shape
# Out:
# (376829, 82)

# %%
minmax_dataset.to_csv("/media/kmdr7/Seagate/DATASETS/Processed-Dataset/03-MinMax-02-Null.csv", index=False)
# Out:
# ...
# To request implementation, send an email to feature_requests@modin.org.
# ...
