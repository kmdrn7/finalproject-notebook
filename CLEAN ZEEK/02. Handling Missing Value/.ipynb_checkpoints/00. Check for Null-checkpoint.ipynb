# %%
import ray
ray.init(address='auto', _redis_password='5241590000000000')

import modin.pandas as pd
import numpy as np
import missingno as msno
# Out:
# 2021-01-24 20:07:07,992	INFO worker.py:656 -- Connecting to existing Ray cluster at address: 192.168.100.35:6379

# %%
dataset = pd.read_csv('/media/kmdr7/Seagate/DATASETS/Merged-IoT-Dataset/Dataset.csv')

# %% [markdown]
# ## Check For Null Value

# %%
dataset.isna().any().any()
# Out:
# False

# %%
msno.matrix(dataset)
# Out:
# <AxesSubplot:>
