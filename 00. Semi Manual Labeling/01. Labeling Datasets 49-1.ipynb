# %%
import pandas as pd

# %%
labels = pd.read_csv('/media/kmdr7/Seagate/DATASETS/IOT-23/CTU-IoT-Malware-Capture-49-1/bro/labels.csv')

# %%
labels
# Out:
#    Id          Field  bro field number   Data Comparator  \
# 0   1      id.resp_p                 6   4554         eq
# 1   2      id.resp_p                 6   8081         eq
# 2   3     conn_state                12     S0         eq
# 3   4  resp_ip_bytes                20  30000         gt
#
#                        Label       type connector
# 0                        C&C  Malicious         -
# 1  PartOfAHorizontalPortScan  Malicious     and 3
# 2  PartOfAHorizontalPortScan  Malicious     and 2
# 3               FileDownload  Malicious         -

# %%
datasets = pd.read_csv('/media/kmdr7/Seagate/DATASETS/IOT-23/CTU-IoT-Malware-Capture-34-1/out/2018-12-21-15-50-14-192.168.1.195.pcap_Flow.csv')
datasets.columns
# Out:
# Index(['Flow ID', 'Src IP', 'Src Port', 'Dst IP', 'Dst Port', 'Protocol',
#        'Timestamp', 'Flow Duration', 'Total Fwd Packet', 'Total Bwd packets',
#        'Total Length of Fwd Packet', 'Total Length of Bwd Packet',
#        'Fwd Packet Length Max', 'Fwd Packet Length Min',
#        'Fwd Packet Length Mean', 'Fwd Packet Length Std',
#        'Bwd Packet Length Max', 'Bwd Packet Length Min',
#        'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s',
#        'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#        'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std',
#        'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean',
#        'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
#        'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Packet Length Min', 'Packet Length Max', 'Packet Length Mean',
# ...

# %%
malware = datasets[
    (datasets["Dst Port"] == 4554) |
    (datasets["Dst Port"] == 8081) & (datasets["Dst IP"] == "123.59.209.185") |
    (datasets["Dst IP"] == "71.61.66.148") |
    (datasets["Dst IP"] == "74.91.117.248")
]

# %%
malware
# Out:
#                                         Flow ID         Src IP  Src Port  \
# 19    192.168.1.195-185.244.25.235-48986-6667-6  192.168.1.195     48986
# 23    192.168.1.195-185.244.25.235-48994-6667-6  192.168.1.195     48994
# 24    192.168.1.195-185.244.25.235-49000-6667-6  192.168.1.195     49000
# 25    192.168.1.195-185.244.25.235-49002-6667-6  192.168.1.195     49002
# 26    192.168.1.195-185.244.25.235-49012-6667-6  192.168.1.195     49012
# ...                                         ...            ...       ...
# 6630  192.168.1.195-185.244.25.235-50692-6667-6  192.168.1.195     50692
# 6631  192.168.1.195-185.244.25.235-56318-6667-6  192.168.1.195     56318
# 6632  192.168.1.195-185.244.25.235-54154-6667-6  192.168.1.195     54154
# 6633  192.168.1.195-185.244.25.235-55994-6667-6  192.168.1.195     55994
# 6634  192.168.1.195-185.244.25.235-50986-6667-6  192.168.1.195     50986
#
#               Dst IP  Dst Port  Protocol               Timestamp  \
# ...

# %%
benign = datasets[
    (datasets["Dst Port"] != 6667) &
    (datasets["Dst Port"] != 63798) &
    (datasets["Dst Port"] != 256) &
    (datasets["Dst Port"] != 5376) &
    (datasets["Dst IP"] != "123.59.209.185") &
    (datasets["Dst IP"] != "71.61.66.148") &
    (datasets["Dst IP"] != "74.91.117.248")
]

# %%
benign
# Out:
#                                         Flow ID          Src IP  Src Port  \
# 0       192.168.1.195-185.244.25.235-41040-80-6   192.168.1.195     41040
# 1       192.168.1.195-185.244.25.235-41040-80-6   192.168.1.195     41040
# 2       192.168.1.195-185.244.25.235-41042-80-6   192.168.1.195     41042
# 3       192.168.1.195-185.244.25.235-41044-80-6   192.168.1.195     41044
# 4       192.168.1.195-185.244.25.235-41046-80-6   192.168.1.195     41046
# ...                                         ...             ...       ...
# 6562  185.244.25.235-192.168.1.195-6667-50206-6  185.244.25.235      6667
# 6577      192.168.1.195-192.168.1.1-42540-53-17   192.168.1.195     42540
# 6599      192.168.1.195-192.168.1.1-53959-53-17   192.168.1.195     53959
# 6605      192.168.1.195-192.168.1.1-32807-53-17   192.168.1.195     32807
# 6626      192.168.1.195-192.168.1.1-33238-53-17   192.168.1.195     33238
#
#               Dst IP  Dst Port  Protocol               Timestamp  \
# ...

# %%
5148 + 1487
# Out:
# 6635
