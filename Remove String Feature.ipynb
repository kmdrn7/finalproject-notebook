# %%
import pandas as pd

# %%
dataset = pd.read_csv("/media/kmdr7/Seagate/DATASETS/IOT-23/Final Dataset/dataset.csv")
dataset
# Out:
#                                      Flow ID         Src IP  Src Port  \
# 0    192.168.1.199-46.101.251.172-59222-80-6  192.168.1.199     59222
# 1    192.168.1.199-46.101.251.172-59224-80-6  192.168.1.199     59224
# 2    192.168.1.199-46.101.251.172-59224-80-6  192.168.1.199     59224
# 3    192.168.1.199-46.101.251.172-59226-80-6  192.168.1.199     59226
# 4    192.168.1.199-46.101.251.172-59228-80-6  192.168.1.199     59228
# ..                                       ...            ...       ...
# 268                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1         0
# 269                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1         0
# 270                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1         0
# 271                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1         0
# 272                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1         0
#
#              Dst IP  Dst Port  Protocol               Timestamp  \
# ...

# %%
dataset.columns
# Out:
# Index(['Flow ID', 'Src IP', 'Src Port', 'Dst IP', 'Dst Port', 'Protocol',
#        'Timestamp', 'Flow Duration', 'Total Fwd Packet', 'Total Bwd packets',
#        'Total Length of Fwd Packet', 'Total Length of Bwd Packet',
#        'Fwd Packet Length Max', 'Fwd Packet Length Min',
#        'Fwd Packet Length Mean', 'Fwd Packet Length Std',
#        'Bwd Packet Length Max', 'Bwd Packet Length Min',
#        'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s',
#        'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#        'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std',
#        'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean',
#        'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
#        'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Packet Length Min', 'Packet Length Max', 'Packet Length Mean',
# ...

# %%
print("Jumlah fitur sebelum di drop: " + str(len(dataset.columns)))
# Out:
# Jumlah fitur sebelum di drop: 84

# %%
final_dataset = dataset.drop(
    columns=[
        "Flow ID",
        "Src IP",
        "Src Port",
        "Dst IP",
        "Dst Port",
        "Timestamp"
    ]
)

# %%
final_dataset.columns
# Out:
# Index(['Protocol', 'Flow Duration', 'Total Fwd Packet', 'Total Bwd packets',
#        'Total Length of Fwd Packet', 'Total Length of Bwd Packet',
#        'Fwd Packet Length Max', 'Fwd Packet Length Min',
#        'Fwd Packet Length Mean', 'Fwd Packet Length Std',
#        'Bwd Packet Length Max', 'Bwd Packet Length Min',
#        'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s',
#        'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#        'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std',
#        'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean',
#        'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
#        'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Packet Length Min', 'Packet Length Max', 'Packet Length Mean',
#        'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
# ...

# %%
print("Jumlah fitur setelah di drop: " + str(len(final_dataset.columns)))
# Out:
# Jumlah fitur setelah di drop: 78

# %%
final_dataset.to_csv("/media/kmdr7/Seagate/DATASETS/IOT-23/Final Dataset/removed_string_dataset.csv", index=False)
