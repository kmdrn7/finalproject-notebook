# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA

pd.options.display.max_rows = 100

# %%
dataset = pd.read_csv('/media/kmdr7/Seagate/TA/DATASETS/DatasetSampled.csv')
x = dataset.drop(["Label"], axis=1)
y = dataset[["Label"]]

# %%
tsne = TSNE(n_components=2, verbose=1, random_state=0)
z = tsne.fit_transform(x)
z
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 237947 samples in 0.007s...
# [t-SNE] Computed neighbors for 237947 samples in 855.837s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 237947
# [t-SNE] Computed conditional probabilities for sample 2000 / 237947
# [t-SNE] Computed conditional probabilities for sample 3000 / 237947
# [t-SNE] Computed conditional probabilities for sample 4000 / 237947
# [t-SNE] Computed conditional probabilities for sample 5000 / 237947
# [t-SNE] Computed conditional probabilities for sample 6000 / 237947
# [t-SNE] Computed conditional probabilities for sample 7000 / 237947
# [t-SNE] Computed conditional probabilities for sample 8000 / 237947
# [t-SNE] Computed conditional probabilities for sample 9000 / 237947
# [t-SNE] Computed conditional probabilities for sample 10000 / 237947
# [t-SNE] Computed conditional probabilities for sample 11000 / 237947
# [t-SNE] Computed conditional probabilities for sample 12000 / 237947
# [t-SNE] Computed conditional probabilities for sample 13000 / 237947
# [t-SNE] Computed conditional probabilities for sample 14000 / 237947
# [t-SNE] Computed conditional probabilities for sample 15000 / 237947
# [t-SNE] Computed conditional probabilities for sample 16000 / 237947
# [t-SNE] Computed conditional probabilities for sample 17000 / 237947
# [t-SNE] Computed conditional probabilities for sample 18000 / 237947
# [t-SNE] Computed conditional probabilities for sample 19000 / 237947
# [t-SNE] Computed conditional probabilities for sample 20000 / 237947
# [t-SNE] Computed conditional probabilities for sample 21000 / 237947
# [t-SNE] Computed conditional probabilities for sample 22000 / 237947
# [t-SNE] Computed conditional probabilities for sample 23000 / 237947
# [t-SNE] Computed conditional probabilities for sample 24000 / 237947
# [t-SNE] Computed conditional probabilities for sample 25000 / 237947
# [t-SNE] Computed conditional probabilities for sample 26000 / 237947
# [t-SNE] Computed conditional probabilities for sample 27000 / 237947
# [t-SNE] Computed conditional probabilities for sample 28000 / 237947
# [t-SNE] Computed conditional probabilities for sample 29000 / 237947
# [t-SNE] Computed conditional probabilities for sample 30000 / 237947
# [t-SNE] Computed conditional probabilities for sample 31000 / 237947
# [t-SNE] Computed conditional probabilities for sample 32000 / 237947
# [t-SNE] Computed conditional probabilities for sample 33000 / 237947
# [t-SNE] Computed conditional probabilities for sample 34000 / 237947
# [t-SNE] Computed conditional probabilities for sample 35000 / 237947
# [t-SNE] Computed conditional probabilities for sample 36000 / 237947
# [t-SNE] Computed conditional probabilities for sample 37000 / 237947
# [t-SNE] Computed conditional probabilities for sample 38000 / 237947
# [t-SNE] Computed conditional probabilities for sample 39000 / 237947
# [t-SNE] Computed conditional probabilities for sample 40000 / 237947
# [t-SNE] Computed conditional probabilities for sample 41000 / 237947
# [t-SNE] Computed conditional probabilities for sample 42000 / 237947
# [t-SNE] Computed conditional probabilities for sample 43000 / 237947
# [t-SNE] Computed conditional probabilities for sample 44000 / 237947
# [t-SNE] Computed conditional probabilities for sample 45000 / 237947
# [t-SNE] Computed conditional probabilities for sample 46000 / 237947
# [t-SNE] Computed conditional probabilities for sample 47000 / 237947
# [t-SNE] Computed conditional probabilities for sample 48000 / 237947
# [t-SNE] Computed conditional probabilities for sample 49000 / 237947
# [t-SNE] Computed conditional probabilities for sample 50000 / 237947
# [t-SNE] Computed conditional probabilities for sample 51000 / 237947
# [t-SNE] Computed conditional probabilities for sample 52000 / 237947
# [t-SNE] Computed conditional probabilities for sample 53000 / 237947
# [t-SNE] Computed conditional probabilities for sample 54000 / 237947
# [t-SNE] Computed conditional probabilities for sample 55000 / 237947
# [t-SNE] Computed conditional probabilities for sample 56000 / 237947
# [t-SNE] Computed conditional probabilities for sample 57000 / 237947
# [t-SNE] Computed conditional probabilities for sample 58000 / 237947
# [t-SNE] Computed conditional probabilities for sample 59000 / 237947
# [t-SNE] Computed conditional probabilities for sample 60000 / 237947
# [t-SNE] Computed conditional probabilities for sample 61000 / 237947
# [t-SNE] Computed conditional probabilities for sample 62000 / 237947
# [t-SNE] Computed conditional probabilities for sample 63000 / 237947
# [t-SNE] Computed conditional probabilities for sample 64000 / 237947
# [t-SNE] Computed conditional probabilities for sample 65000 / 237947
# [t-SNE] Computed conditional probabilities for sample 66000 / 237947
# [t-SNE] Computed conditional probabilities for sample 67000 / 237947
# [t-SNE] Computed conditional probabilities for sample 68000 / 237947
# [t-SNE] Computed conditional probabilities for sample 69000 / 237947
# [t-SNE] Computed conditional probabilities for sample 70000 / 237947
# [t-SNE] Computed conditional probabilities for sample 71000 / 237947
# [t-SNE] Computed conditional probabilities for sample 72000 / 237947
# [t-SNE] Computed conditional probabilities for sample 73000 / 237947
# [t-SNE] Computed conditional probabilities for sample 74000 / 237947
# [t-SNE] Computed conditional probabilities for sample 75000 / 237947
# [t-SNE] Computed conditional probabilities for sample 76000 / 237947
# [t-SNE] Computed conditional probabilities for sample 77000 / 237947
# [t-SNE] Computed conditional probabilities for sample 78000 / 237947
# [t-SNE] Computed conditional probabilities for sample 79000 / 237947
# [t-SNE] Computed conditional probabilities for sample 80000 / 237947
# [t-SNE] Computed conditional probabilities for sample 81000 / 237947
# [t-SNE] Computed conditional probabilities for sample 82000 / 237947
# [t-SNE] Computed conditional probabilities for sample 83000 / 237947
# [t-SNE] Computed conditional probabilities for sample 84000 / 237947
# [t-SNE] Computed conditional probabilities for sample 85000 / 237947
# [t-SNE] Computed conditional probabilities for sample 86000 / 237947
# [t-SNE] Computed conditional probabilities for sample 87000 / 237947
# [t-SNE] Computed conditional probabilities for sample 88000 / 237947
# [t-SNE] Computed conditional probabilities for sample 89000 / 237947
# [t-SNE] Computed conditional probabilities for sample 90000 / 237947
# [t-SNE] Computed conditional probabilities for sample 91000 / 237947
# [t-SNE] Computed conditional probabilities for sample 92000 / 237947
# [t-SNE] Computed conditional probabilities for sample 93000 / 237947
# [t-SNE] Computed conditional probabilities for sample 94000 / 237947
# [t-SNE] Computed conditional probabilities for sample 95000 / 237947
# [t-SNE] Computed conditional probabilities for sample 96000 / 237947
# [t-SNE] Computed conditional probabilities for sample 97000 / 237947
# [t-SNE] Computed conditional probabilities for sample 98000 / 237947
# [t-SNE] Computed conditional probabilities for sample 99000 / 237947
# [t-SNE] Computed conditional probabilities for sample 100000 / 237947
# [t-SNE] Computed conditional probabilities for sample 101000 / 237947
# [t-SNE] Computed conditional probabilities for sample 102000 / 237947
# [t-SNE] Computed conditional probabilities for sample 103000 / 237947
# [t-SNE] Computed conditional probabilities for sample 104000 / 237947
# [t-SNE] Computed conditional probabilities for sample 105000 / 237947
# [t-SNE] Computed conditional probabilities for sample 106000 / 237947
# [t-SNE] Computed conditional probabilities for sample 107000 / 237947
# [t-SNE] Computed conditional probabilities for sample 108000 / 237947
# [t-SNE] Computed conditional probabilities for sample 109000 / 237947
# [t-SNE] Computed conditional probabilities for sample 110000 / 237947
# [t-SNE] Computed conditional probabilities for sample 111000 / 237947
# [t-SNE] Computed conditional probabilities for sample 112000 / 237947
# [t-SNE] Computed conditional probabilities for sample 113000 / 237947
# [t-SNE] Computed conditional probabilities for sample 114000 / 237947
# [t-SNE] Computed conditional probabilities for sample 115000 / 237947
# [t-SNE] Computed conditional probabilities for sample 116000 / 237947
# [t-SNE] Computed conditional probabilities for sample 117000 / 237947
# [t-SNE] Computed conditional probabilities for sample 118000 / 237947
# [t-SNE] Computed conditional probabilities for sample 119000 / 237947
# [t-SNE] Computed conditional probabilities for sample 120000 / 237947
# [t-SNE] Computed conditional probabilities for sample 121000 / 237947
# [t-SNE] Computed conditional probabilities for sample 122000 / 237947
# [t-SNE] Computed conditional probabilities for sample 123000 / 237947
# [t-SNE] Computed conditional probabilities for sample 124000 / 237947
# [t-SNE] Computed conditional probabilities for sample 125000 / 237947
# [t-SNE] Computed conditional probabilities for sample 126000 / 237947
# [t-SNE] Computed conditional probabilities for sample 127000 / 237947
# [t-SNE] Computed conditional probabilities for sample 128000 / 237947
# [t-SNE] Computed conditional probabilities for sample 129000 / 237947
# [t-SNE] Computed conditional probabilities for sample 130000 / 237947
# [t-SNE] Computed conditional probabilities for sample 131000 / 237947
# [t-SNE] Computed conditional probabilities for sample 132000 / 237947
# [t-SNE] Computed conditional probabilities for sample 133000 / 237947
# [t-SNE] Computed conditional probabilities for sample 134000 / 237947
# [t-SNE] Computed conditional probabilities for sample 135000 / 237947
# [t-SNE] Computed conditional probabilities for sample 136000 / 237947
# [t-SNE] Computed conditional probabilities for sample 137000 / 237947
# [t-SNE] Computed conditional probabilities for sample 138000 / 237947
# [t-SNE] Computed conditional probabilities for sample 139000 / 237947
# [t-SNE] Computed conditional probabilities for sample 140000 / 237947
# [t-SNE] Computed conditional probabilities for sample 141000 / 237947
# [t-SNE] Computed conditional probabilities for sample 142000 / 237947
# [t-SNE] Computed conditional probabilities for sample 143000 / 237947
# [t-SNE] Computed conditional probabilities for sample 144000 / 237947
# [t-SNE] Computed conditional probabilities for sample 145000 / 237947
# [t-SNE] Computed conditional probabilities for sample 146000 / 237947
# [t-SNE] Computed conditional probabilities for sample 147000 / 237947
# [t-SNE] Computed conditional probabilities for sample 148000 / 237947
# [t-SNE] Computed conditional probabilities for sample 149000 / 237947
# [t-SNE] Computed conditional probabilities for sample 150000 / 237947
# [t-SNE] Computed conditional probabilities for sample 151000 / 237947
# [t-SNE] Computed conditional probabilities for sample 152000 / 237947
# [t-SNE] Computed conditional probabilities for sample 153000 / 237947
# [t-SNE] Computed conditional probabilities for sample 154000 / 237947
# [t-SNE] Computed conditional probabilities for sample 155000 / 237947
# [t-SNE] Computed conditional probabilities for sample 156000 / 237947
# [t-SNE] Computed conditional probabilities for sample 157000 / 237947
# [t-SNE] Computed conditional probabilities for sample 158000 / 237947
# [t-SNE] Computed conditional probabilities for sample 159000 / 237947
# [t-SNE] Computed conditional probabilities for sample 160000 / 237947
# [t-SNE] Computed conditional probabilities for sample 161000 / 237947
# [t-SNE] Computed conditional probabilities for sample 162000 / 237947
# [t-SNE] Computed conditional probabilities for sample 163000 / 237947
# [t-SNE] Computed conditional probabilities for sample 164000 / 237947
# [t-SNE] Computed conditional probabilities for sample 165000 / 237947
# [t-SNE] Computed conditional probabilities for sample 166000 / 237947
# [t-SNE] Computed conditional probabilities for sample 167000 / 237947
# [t-SNE] Computed conditional probabilities for sample 168000 / 237947
# [t-SNE] Computed conditional probabilities for sample 169000 / 237947
# [t-SNE] Computed conditional probabilities for sample 170000 / 237947
# [t-SNE] Computed conditional probabilities for sample 171000 / 237947
# [t-SNE] Computed conditional probabilities for sample 172000 / 237947
# [t-SNE] Computed conditional probabilities for sample 173000 / 237947
# [t-SNE] Computed conditional probabilities for sample 174000 / 237947
# [t-SNE] Computed conditional probabilities for sample 175000 / 237947
# [t-SNE] Computed conditional probabilities for sample 176000 / 237947
# [t-SNE] Computed conditional probabilities for sample 177000 / 237947
# [t-SNE] Computed conditional probabilities for sample 178000 / 237947
# [t-SNE] Computed conditional probabilities for sample 179000 / 237947
# [t-SNE] Computed conditional probabilities for sample 180000 / 237947
# [t-SNE] Computed conditional probabilities for sample 181000 / 237947
# [t-SNE] Computed conditional probabilities for sample 182000 / 237947
# [t-SNE] Computed conditional probabilities for sample 183000 / 237947
# [t-SNE] Computed conditional probabilities for sample 184000 / 237947
# [t-SNE] Computed conditional probabilities for sample 185000 / 237947
# [t-SNE] Computed conditional probabilities for sample 186000 / 237947
# [t-SNE] Computed conditional probabilities for sample 187000 / 237947
# [t-SNE] Computed conditional probabilities for sample 188000 / 237947
# [t-SNE] Computed conditional probabilities for sample 189000 / 237947
# [t-SNE] Computed conditional probabilities for sample 190000 / 237947
# [t-SNE] Computed conditional probabilities for sample 191000 / 237947
# [t-SNE] Computed conditional probabilities for sample 192000 / 237947
# [t-SNE] Computed conditional probabilities for sample 193000 / 237947
# [t-SNE] Computed conditional probabilities for sample 194000 / 237947
# [t-SNE] Computed conditional probabilities for sample 195000 / 237947
# [t-SNE] Computed conditional probabilities for sample 196000 / 237947
# [t-SNE] Computed conditional probabilities for sample 197000 / 237947
# [t-SNE] Computed conditional probabilities for sample 198000 / 237947
# [t-SNE] Computed conditional probabilities for sample 199000 / 237947
# [t-SNE] Computed conditional probabilities for sample 200000 / 237947
# [t-SNE] Computed conditional probabilities for sample 201000 / 237947
# [t-SNE] Computed conditional probabilities for sample 202000 / 237947
# [t-SNE] Computed conditional probabilities for sample 203000 / 237947
# [t-SNE] Computed conditional probabilities for sample 204000 / 237947
# [t-SNE] Computed conditional probabilities for sample 205000 / 237947
# [t-SNE] Computed conditional probabilities for sample 206000 / 237947
# [t-SNE] Computed conditional probabilities for sample 207000 / 237947
# [t-SNE] Computed conditional probabilities for sample 208000 / 237947
# [t-SNE] Computed conditional probabilities for sample 209000 / 237947
# [t-SNE] Computed conditional probabilities for sample 210000 / 237947
# [t-SNE] Computed conditional probabilities for sample 211000 / 237947
# [t-SNE] Computed conditional probabilities for sample 212000 / 237947
# [t-SNE] Computed conditional probabilities for sample 213000 / 237947
# [t-SNE] Computed conditional probabilities for sample 214000 / 237947
# [t-SNE] Computed conditional probabilities for sample 215000 / 237947
# [t-SNE] Computed conditional probabilities for sample 216000 / 237947
# [t-SNE] Computed conditional probabilities for sample 217000 / 237947
# [t-SNE] Computed conditional probabilities for sample 218000 / 237947
# [t-SNE] Computed conditional probabilities for sample 219000 / 237947
# [t-SNE] Computed conditional probabilities for sample 220000 / 237947
# [t-SNE] Computed conditional probabilities for sample 221000 / 237947
# [t-SNE] Computed conditional probabilities for sample 222000 / 237947
# [t-SNE] Computed conditional probabilities for sample 223000 / 237947
# [t-SNE] Computed conditional probabilities for sample 224000 / 237947
# [t-SNE] Computed conditional probabilities for sample 225000 / 237947
# [t-SNE] Computed conditional probabilities for sample 226000 / 237947
# [t-SNE] Computed conditional probabilities for sample 227000 / 237947
# [t-SNE] Computed conditional probabilities for sample 228000 / 237947
# [t-SNE] Computed conditional probabilities for sample 229000 / 237947
# [t-SNE] Computed conditional probabilities for sample 230000 / 237947
# [t-SNE] Computed conditional probabilities for sample 231000 / 237947
# [t-SNE] Computed conditional probabilities for sample 232000 / 237947
# [t-SNE] Computed conditional probabilities for sample 233000 / 237947
# [t-SNE] Computed conditional probabilities for sample 234000 / 237947
# [t-SNE] Computed conditional probabilities for sample 235000 / 237947
# [t-SNE] Computed conditional probabilities for sample 236000 / 237947
# [t-SNE] Computed conditional probabilities for sample 237000 / 237947
# [t-SNE] Computed conditional probabilities for sample 237947 / 237947
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 97.241188
# [t-SNE] KL divergence after 1000 iterations: 3.086317
# array([[  2.8661659 ,  29.501392  ],
#        [ -6.2344522 ,  -5.1599445 ],
#        [ -0.21420579, -16.210238  ],
#        ...,
#        [ 23.665163  ,   7.9279327 ],
#        [ -0.3559988 , -22.64393   ],
#        [-22.895447  ,  24.958498  ]], dtype=float32)

# %%
z.shape
# Out:
# (237947, 2)

# %%
df = pd.DataFrame()
df[["y"]] = y
df[["comp-1"]] = z[:,0]
df[["comp-2"]] = z[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 2),
                data=df).set(title="Malware IoT T-SNE projection")
# Out:
# [Text(0.5, 1.0, 'Malware IoT T-SNE projection')]
