# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("/media/kmdr7/Seagate/DATASETS/IOT-23-CIC/Dataset/Dataset.csv")
dataset.head(10)
# Out:
#    Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0         0      108820696                14                  0
# 1        17       64001377                 2                  2
# 2        17           3737                 1                  1
# 3        17          26467                 1                  1
# 4        17          14733                 1                  1
# 5         0       91000263                12                  0
# 6        17       64001527                 2                  2
# 7        17           3983                 1                  1
# 8        17          26718                 1                  1
# 9        17          14731                 1                  1
#
#    Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                         0.0                         0.0
# 1                        96.0                        96.0
# 2                        48.0                        48.0
# ...

# %%
# replace infinite val with nan
dataset.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Cek missing values
dataset.isna().sum().sum()
# Out:
# 70

# %% [markdown]
# ## Replace Missing with LR

# %%
dataset.interpolate(method ='linear', limit_direction ='forward', inplace=True)
dataset.to_csv('/media/kmdr7/Seagate/DATASETS/IOT-23-CIC/Dataset/2-LR.csv', index=False)

# %%
# Cek missing values
dataset.isna().sum().sum()
# Out:
# 0
