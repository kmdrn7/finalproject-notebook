# %%
import dask.dataframe as dd
from dask.distributed import Client

import pandas as pd
import numpy as np

client = Client("tcp://192.168.100.20:8786")
# Out:
# /work/code/Env/lib/python3.8/site-packages/distributed/client.py:1148: VersionMismatchWarning: Mismatched versions found
#
# +---------+--------+-----------+----------------------+
# | Package | client | scheduler | workers              |
# +---------+--------+-----------+----------------------+
# | numpy   | 1.19.5 | 1.19.5    | {'1.19.0', '1.19.5'} |
# | tornado | 6.1    | 6.1       | {'6.0.4', '6.1'}     |
# +---------+--------+-----------+----------------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
dataset = dd.read_csv("s3://final-project/Dataset.csv", storage_options={
    "key": "andikaahmad",
    "secret": "andikaahmad",
    "client_kwargs": {
        "endpoint_url": "http://192.168.100.20:9090",
    },
})
dataset.head(10)
# Out:
#    Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0         6        1176287                 1                  2
# 1         6          11305                 6                  4
# 2         6        2870937                 8                  5
# 3         6           7383                 4                  5
# 4         6            946                 2                  0
# 5         6        2655343                 7                  4
# 6         6        2682811                 7                  4
# 7         6          10466                 5                  5
# 8         6           6929                 4                  5
# 9         6           1175                 2                  0
#
#    Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                         0.0                         0.0
# 1                       338.0                       193.0
# 2                       360.0                       420.0
# ...

# %%
# replace infinite val with nan
dataset = dataset.replace([np.inf, -np.inf], np.nan)

# %%
# Cek missing values
dataset.isna().sum().sum().compute()
# Out:
# 0

# %% [markdown]
# ## Replace Missing with LR

# %%
# dataset = dataset.dropna()
dataset.to_csv('s3://final-project/Dataset-Drop.csv', single_file=True, compute=True, storage_options={
    "key": "andikaahmad",
    "secret": "andikaahmad",
    "client_kwargs": {
        "endpoint_url": "http://192.168.100.20:9090",
    },
})
# Out:
# /work/code/Env/lib/python3.8/site-packages/dask/dataframe/io/csv.py:855: UserWarning: Appending data to a network storage system may not work.
#   warn("Appending data to a network storage system may not work.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f0182bbaf813> in <module>
#       1 # dataset = dataset.dropna()
# ----> 2 dataset.to_csv('s3://final-project/Dataset-Drop.csv', single_file=True, compute=True, storage_options={
#       3     "key": "andikaahmad",
#       4     "secret": "andikaahmad",
#       5     "client_kwargs": {
#
# /work/code/Env/lib/python3.8/site-packages/dask/dataframe/core.py in to_csv(self, filename, **kwargs)
#    1465         from .io import to_csv
#    1466
# -> 1467         return to_csv(self, filename, **kwargs)
#    1468
#    1469     def to_sql(
#
# ...

# %%
# Cek missing values
dataset.isna().sum().sum().compute()
# Out:
# 0
