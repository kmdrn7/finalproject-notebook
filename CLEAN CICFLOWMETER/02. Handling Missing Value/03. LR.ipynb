# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("/media/kmdr7/Seagate/TA/DATASETS/Dataset.csv")
dataset.head(10)
# Out:
#    Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0         6        1176287                 1                  2
# 1         6          11305                 6                  4
# 2         6        2870937                 8                  5
# 3         6           7383                 4                  5
# 4         6            946                 2                  0
# 5         6        2655343                 7                  4
# 6         6        2682811                 7                  4
# 7         6          10466                 5                  5
# 8         6           6929                 4                  5
# 9         6           1175                 2                  0
#
#    Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                         0.0                         0.0
# 1                       338.0                       193.0
# 2                       360.0                       420.0
# ...

# %%
# replace infinite val with nan
dataset.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Cek missing values
dataset.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Replace Missing with LR

# %%
dataset.interpolate(method ='linear', limit_direction ='forward', inplace=True)
dataset.to_csv('/media/kmdr7/Seagate/TA/DATASETS/Dataset-LR.csv', index=False)

# %%
# Cek missing values
dataset.isna().sum().sum()
# Out:
# 0
