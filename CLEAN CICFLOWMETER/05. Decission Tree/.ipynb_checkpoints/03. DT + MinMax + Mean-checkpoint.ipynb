# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, f1_score, precision_score

# %%
def plot_confusion_matrix(data, labels, output_filename):
    seaborn.set(color_codes=True)
    plt.figure(1, figsize=(9, 6))
    plt.title("Confusion Matrix")
    seaborn.set(font_scale=1.4)
    ax = seaborn.heatmap(data, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Scale'})
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
    ax.set(ylabel="True Label", xlabel="Predicted Label")
    plt.show()

# %%
dataset = pd.read_csv("/media/kmdr7/Seagate/DATASETS/IOT-23-CIC/Dataset/2-Drop.csv")
clean_dataset = dataset.drop(columns=["Label"])
label = dataset["Label"]
dataset
# Out:
#         Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0              0      108820696                14                  0
# 1             17       64001377                 2                  2
# 2             17           3737                 1                  1
# 3             17          26467                 1                  1
# 4             17          14733                 1                  1
# ...          ...            ...               ...                ...
# 553579         6        7179174                 4                  0
# 553580         6        7219390                 4                  0
# 553581         6          42726                 2                  0
# 553582         6        7226381                 4                  0
# 553583         6        7215387                 4                  0
#
#         Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                              0.0                         0.0
# 1                             96.0                        96.0
# 2                             48.0                        48.0
# 3                             48.0                        48.0
# 4                             48.0                        48.0
# ...                            ...                         ...
# 553579                         0.0                         0.0
# 553580                         0.0                         0.0
# 553581                         0.0                         0.0
# 553582                         0.0                         0.0
# 553583                         0.0                         0.0
#
#         Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                         0.0                    0.0                     0.0
# 1                        48.0                   48.0                    48.0
# 2                        48.0                   48.0                    48.0
# 3                        48.0                   48.0                    48.0
# 4                        48.0                   48.0                    48.0
# ...                       ...                    ...                     ...
# 553579                    0.0                    0.0                     0.0
# 553580                    0.0                    0.0                     0.0
# 553581                    0.0                    0.0                     0.0
# 553582                    0.0                    0.0                     0.0
# 553583                    0.0                    0.0                     0.0
#
#         Fwd Packet Length Std  ...  Fwd Seg Size Min  Active Mean  Active Std  \
# 0                         0.0  ...                 0   207.333333  186.088868
# 1                         0.0  ...                 8  1239.000000    0.000000
# 2                         0.0  ...                 8     0.000000    0.000000
# 3                         0.0  ...                 8     0.000000    0.000000
# 4                         0.0  ...                 8     0.000000    0.000000
# ...                       ...  ...               ...          ...         ...
# 553579                    0.0  ...                40     0.000000    0.000000
# 553580                    0.0  ...                40     0.000000    0.000000
# 553581                    0.0  ...                32     0.000000    0.000000
# 553582                    0.0  ...                40     0.000000    0.000000
# 553583                    0.0  ...                40     0.000000    0.000000
#
#         Active Max  Active Min     Idle Mean      Idle Std      Idle Max  \
# 0            498.0         2.0  2.179828e+14  5.767284e+14  1.525880e+15
# 1           1239.0      1239.0  7.629400e+14  1.078960e+15  1.525880e+15
# 2              0.0         0.0  1.525880e+15  0.000000e+00  1.525880e+15
# 3              0.0         0.0  1.525880e+15  0.000000e+00  1.525880e+15
# 4              0.0         0.0  1.525880e+15  0.000000e+00  1.525880e+15
# ...            ...         ...           ...           ...           ...
# 553579         0.0         0.0  1.545410e+15  0.000000e+00  1.545410e+15
# 553580         0.0         0.0  1.545483e+15  0.000000e+00  1.545483e+15
# 553581         0.0         0.0  1.545462e+15  0.000000e+00  1.545462e+15
# 553582         0.0         0.0  1.545481e+15  0.000000e+00  1.545481e+15
# 553583         0.0         0.0  1.545411e+15  0.000000e+00  1.545411e+15
#
#             Idle Min      Label
# 0       5.965355e+06     Benign
# 1       6.399890e+07     Benign
# 2       1.525880e+15     Benign
# 3       1.525880e+15     Benign
# 4       1.525880e+15     Benign
# ...              ...        ...
# 553579  1.545410e+15  Malicious
# 553580  1.545483e+15  Malicious
# 553581  1.545462e+15  Malicious
# 553582  1.545481e+15  Malicious
# 553583  1.545411e+15  Malicious
#
# [553584 rows x 78 columns]

# %%
## Bagi dataset menjadi train dan test
x_train, x_test, y_train, y_test = train_test_split(
    clean_dataset, label, test_size=1/7.0, random_state=1
)

# %%
clf = DecisionTreeClassifier(criterion="entropy", n_jobs=4)
clf.fit(x_train, y_train)
scores = cross_val_score(estimator=clf, X=clean_dataset, y=label, cv=10, n_jobs=8)
print("mean: {:.3f} (std: {:.3f})".format(scores.mean(), scores.std()), end="\n\n" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-f1cad1e88cdb> in <module>
# ----> 1 clf = DecisionTreeClassifier(criterion="entropy", n_jobs=4)
#       2 clf.fit(x_train, y_train)
#       3 scores = cross_val_score(estimator=clf, X=clean_dataset, y=label, cv=10, n_jobs=8)
#       4 print("mean: {:.3f} (std: {:.3f})".format(scores.mean(), scores.std()), end="\n\n" )
#
# /homelab/ta/code/FinalProjectEnv/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# TypeError: __init__() got an unexpected keyword argument 'n_jobs'

# %%
y_pred = clf.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# %%
# Recall
recall = recall_score(y_test, y_pred, average=None)
recall

# %%
# F1 Score
f1 = f1_score(y_test, y_pred, average=None)
f1

# %%
# Precision
precision = precision_score(y_test, y_pred, average=None) * 100
precision

# %%
labels = ["Benign", "Malicious"]
conf = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(conf, labels, "confusion_matrix.png")
