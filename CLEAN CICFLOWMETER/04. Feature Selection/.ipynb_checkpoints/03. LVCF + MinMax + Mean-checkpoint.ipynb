# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_selection import VarianceThreshold

# %%
dataset = pd.read_csv("/media/kmdr7/Seagate/DATASETS/IOT-23-CIC/Dataset/3-MinMax-2-Mean.csv")
clean_dataset = dataset.drop(columns=["Label"])
clean_dataset
# Out:
#         Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0       0.000000       0.906839          0.000111           0.000000
# 1       1.000000       0.533345          0.000009           0.000009
# 2       1.000000       0.000031          0.000000           0.000004
# 3       1.000000       0.000221          0.000000           0.000004
# 4       1.000000       0.000123          0.000000           0.000004
# ...          ...            ...               ...                ...
# 553614  0.352941       0.059826          0.000026           0.000000
# 553615  0.352941       0.060162          0.000026           0.000000
# 553616  0.352941       0.000356          0.000009           0.000000
# 553617  0.352941       0.060220          0.000026           0.000000
# 553618  0.352941       0.060128          0.000026           0.000000
#
#         Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                         0.000000                0.000000e+00
# 1                         0.000004                2.992775e-07
# 2                         0.000002                1.496388e-07
# 3                         0.000002                1.496388e-07
# 4                         0.000002                1.496388e-07
# ...                            ...                         ...
# 553614                    0.000000                0.000000e+00
# 553615                    0.000000                0.000000e+00
# 553616                    0.000000                0.000000e+00
# 553617                    0.000000                0.000000e+00
# 553618                    0.000000                0.000000e+00
#
#         Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                    0.000000               0.000000                0.000000
# 1                    0.010959               0.032609                0.032609
# 2                    0.010959               0.032609                0.032609
# 3                    0.010959               0.032609                0.032609
# 4                    0.010959               0.032609                0.032609
# ...                       ...                    ...                     ...
# 553614               0.000000               0.000000                0.000000
# 553615               0.000000               0.000000                0.000000
# 553616               0.000000               0.000000                0.000000
# 553617               0.000000               0.000000                0.000000
# 553618               0.000000               0.000000                0.000000
#
#         Fwd Packet Length Std  ...  Fwd Act Data Pkts  Fwd Seg Size Min  \
# 0                         0.0  ...           0.000000          0.000000
# 1                         0.0  ...           0.000054          0.181818
# 2                         0.0  ...           0.000000          0.181818
# 3                         0.0  ...           0.000000          0.181818
# 4                         0.0  ...           0.000000          0.181818
# ...                       ...  ...                ...               ...
# 553614                    0.0  ...           0.000000          0.909091
# 553615                    0.0  ...           0.000000          0.909091
# 553616                    0.0  ...           0.000000          0.727273
# 553617                    0.0  ...           0.000000          0.909091
# 553618                    0.0  ...           0.000000          0.909091
#
#         Active Mean  Active Std  Active Max    Active Min  Idle Mean  \
# 0          0.000002    0.000009    0.000004  1.767458e-08   0.102689
# 1          0.000011    0.000000    0.000011  1.094940e-05   0.466360
# 2          0.000000    0.000000    0.000000  0.000000e+00   0.975500
# 3          0.000000    0.000000    0.000000  0.000000e+00   0.975500
# 4          0.000000    0.000000    0.000000  0.000000e+00   0.975500
# ...             ...         ...         ...           ...        ...
# 553614     0.000000    0.000000    0.000000  0.000000e+00   0.988533
# 553615     0.000000    0.000000    0.000000  0.000000e+00   0.988582
# 553616     0.000000    0.000000    0.000000  0.000000e+00   0.988568
# 553617     0.000000    0.000000    0.000000  0.000000e+00   0.988580
# 553618     0.000000    0.000000    0.000000  0.000000e+00   0.988534
#
#         Idle Std      Idle Max      Idle Min
# 0       0.522063  1.177270e-09  6.177845e-10
# 1       0.976691  3.225900e-07  3.775703e-08
# 2       0.000000  1.003482e-06  9.765048e-01
# 3       0.000000  1.221364e-06  9.765048e-01
# 4       0.000000  2.828258e-06  9.765048e-01
# ...          ...           ...           ...
# 553614  0.000000  5.319158e-01  9.890034e-01
# 553615  0.000000  5.339116e-01  9.890503e-01
# 553616  0.000000  5.333360e-01  9.890368e-01
# 553617  0.000000  5.338316e-01  9.890484e-01
# 553618  0.000000  5.319473e-01  9.890041e-01
#
# [553619 rows x 77 columns]

# %% [markdown]
# ## Menghapus feature yang memiliki low variance

# %%
tres = 0.03

lv = VarianceThreshold(threshold=tres)
lv.fit_transform(clean_dataset)

filtered_cols = clean_dataset.drop(
    columns=clean_dataset.columns[lv.get_support()].array
).columns.array

lowvariance_dataset = clean_dataset.drop(columns=filtered_cols)
lowvariance_dataset
# Out:
#         Protocol  Flow Duration  Fwd IAT Total  Bwd IAT Total  FIN Flag Count  \
# 0       0.000000       0.906839       0.906839       0.000000             0.0
# 1       1.000000       0.533345       0.533334       0.533335             0.0
# 2       1.000000       0.000031       0.000000       0.000000             0.0
# 3       1.000000       0.000221       0.000000       0.000000             0.0
# 4       1.000000       0.000123       0.000000       0.000000             0.0
# ...          ...            ...            ...            ...             ...
# 553614  0.352941       0.059826       0.059826       0.000000             0.0
# 553615  0.352941       0.060162       0.060162       0.000000             0.0
# 553616  0.352941       0.000356       0.000356       0.000000             0.0
# 553617  0.352941       0.060220       0.060220       0.000000             0.0
# 553618  0.352941       0.060128       0.060128       0.000000             0.0
#
#         Subflow Fwd Packets  FWD Init Win Bytes  Fwd Seg Size Min  Idle Mean  \
# 0                       1.0            0.000000          0.000000   0.102689
# 1                       0.0            0.000000          0.181818   0.466360
# 2                       0.0            0.000000          0.181818   0.975500
# 3                       0.0            0.000000          0.181818   0.975500
# 4                       0.0            0.000000          0.181818   0.975500
# ...                     ...                 ...               ...        ...
# 553614                  1.0            0.445563          0.909091   0.988533
# 553615                  1.0            0.445563          0.909091   0.988582
# 553616                  1.0            0.007218          0.727273   0.988568
# 553617                  1.0            0.445563          0.909091   0.988580
# 553618                  1.0            0.445563          0.909091   0.988534
#
#         Idle Std      Idle Max      Idle Min
# 0       0.522063  1.177270e-09  6.177845e-10
# 1       0.976691  3.225900e-07  3.775703e-08
# 2       0.000000  1.003482e-06  9.765048e-01
# 3       0.000000  1.221364e-06  9.765048e-01
# 4       0.000000  2.828258e-06  9.765048e-01
# ...          ...           ...           ...
# 553614  0.000000  5.319158e-01  9.890034e-01
# 553615  0.000000  5.339116e-01  9.890503e-01
# 553616  0.000000  5.333360e-01  9.890368e-01
# 553617  0.000000  5.338316e-01  9.890484e-01
# 553618  0.000000  5.319473e-01  9.890041e-01
#
# [553619 rows x 12 columns]

# %%
lowvariance_dataset["Label"] = dataset["Label"].astype('category').cat.codes
lowvariance_dataset["Label"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 553614    1
# 553615    1
# 553616    1
# 553617    1
# 553618    1
# Name: Label, Length: 553619, dtype: int8

# %% [markdown]
# ## Cari korelasi antara fitur dengan target

# %%
plt.figure(figsize=(12,10))
cor = lowvariance_dataset.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Blues)
plt.show()

# %%
cor_target = abs(cor["Label"])
cor_target
# Out:
# Protocol               0.461452
# Flow Duration          0.121872
# Fwd IAT Total          0.120745
# Bwd IAT Total          0.196647
# FIN Flag Count         0.308119
# Subflow Fwd Packets    0.609948
# FWD Init Win Bytes     0.836239
# Fwd Seg Size Min       0.750384
# Idle Mean              0.280618
# Idle Std               0.426287
# Idle Max               0.800307
# Idle Min               0.375665
# Label                  1.000000
# Name: Label, dtype: float64

# %%
relevant_features = cor_target[cor_target>0.2]
relevant_features
# Out:
# Protocol               0.461452
# FIN Flag Count         0.308119
# Subflow Fwd Packets    0.609948
# FWD Init Win Bytes     0.836239
# Fwd Seg Size Min       0.750384
# Idle Mean              0.280618
# Idle Std               0.426287
# Idle Max               0.800307
# Idle Min               0.375665
# Label                  1.000000
# Name: Label, dtype: float64

# %% [markdown]
# ## Hasil lowvariance filter + pearson correlation filter

# %%
all_feature = set(dataset.columns)
rel_feature = set(relevant_features.index)
removed_feature = list(all_feature - rel_feature)
removed_feature

lowvariance_correlationfilter_dataset = dataset.drop(columns=removed_feature)
lowvariance_correlationfilter_dataset
# Out:
#         Protocol  FIN Flag Count  Subflow Fwd Packets  FWD Init Win Bytes  \
# 0       0.000000             0.0                  1.0            0.000000
# 1       1.000000             0.0                  0.0            0.000000
# 2       1.000000             0.0                  0.0            0.000000
# 3       1.000000             0.0                  0.0            0.000000
# 4       1.000000             0.0                  0.0            0.000000
# ...          ...             ...                  ...                 ...
# 553614  0.352941             0.0                  1.0            0.445563
# 553615  0.352941             0.0                  1.0            0.445563
# 553616  0.352941             0.0                  1.0            0.007218
# 553617  0.352941             0.0                  1.0            0.445563
# 553618  0.352941             0.0                  1.0            0.445563
#
#         Fwd Seg Size Min  Idle Mean  Idle Std      Idle Max      Idle Min  \
# 0               0.000000   0.102689  0.522063  1.177270e-09  6.177845e-10
# 1               0.181818   0.466360  0.976691  3.225900e-07  3.775703e-08
# 2               0.181818   0.975500  0.000000  1.003482e-06  9.765048e-01
# 3               0.181818   0.975500  0.000000  1.221364e-06  9.765048e-01
# 4               0.181818   0.975500  0.000000  2.828258e-06  9.765048e-01
# ...                  ...        ...       ...           ...           ...
# 553614          0.909091   0.988533  0.000000  5.319158e-01  9.890034e-01
# 553615          0.909091   0.988582  0.000000  5.339116e-01  9.890503e-01
# 553616          0.727273   0.988568  0.000000  5.333360e-01  9.890368e-01
# 553617          0.909091   0.988580  0.000000  5.338316e-01  9.890484e-01
# 553618          0.909091   0.988534  0.000000  5.319473e-01  9.890041e-01
#
#             Label
# 0          Benign
# 1          Benign
# 2          Benign
# 3          Benign
# 4          Benign
# ...           ...
# 553614  Malicious
# 553615  Malicious
# 553616  Malicious
# 553617  Malicious
# 553618  Malicious
#
# [553619 rows x 10 columns]

# %%
lowvariance_correlationfilter_dataset.to_csv("/media/kmdr7/Seagate/DATASETS/IOT-23-CIC/Dataset/4-LVCF-3-MinMax-2-Mean.csv", index=False)
