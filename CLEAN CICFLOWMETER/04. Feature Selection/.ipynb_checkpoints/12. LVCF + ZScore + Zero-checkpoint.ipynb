# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_selection import VarianceThreshold

# %%
dataset = pd.read_csv("/media/kmdr7/Seagate/DATASETS/IOT-23-CIC/Dataset/3-ZScore-2-Zero.csv")
clean_dataset = dataset.drop(columns=["Label"])
clean_dataset
# Out:
#         Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0      -1.713649       3.396582          0.039738          -0.009041
# 1       1.876708       1.760380         -0.027036          -0.002532
# 2       1.876708      -0.575959         -0.032600          -0.005787
# 3       1.876708      -0.575129         -0.032600          -0.005787
# 4       1.876708      -0.575557         -0.032600          -0.005787
# ...          ...            ...               ...                ...
# 553614 -0.446464      -0.314008         -0.015907          -0.009041
# 553615 -0.446464      -0.312539         -0.015907          -0.009041
# 553616 -0.446464      -0.574535         -0.027036          -0.009041
# 553617 -0.446464      -0.312284         -0.015907          -0.009041
# 553618 -0.446464      -0.312686         -0.015907          -0.009041
#
#         Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                        -0.014834                   -0.002925
# 1                        -0.012753                   -0.002703
# 2                        -0.013794                   -0.002814
# 3                        -0.013794                   -0.002814
# 4                        -0.013794                   -0.002814
# ...                            ...                         ...
# 553614                   -0.014834                   -0.002925
# 553615                   -0.014834                   -0.002925
# 553616                   -0.014834                   -0.002925
# 553617                   -0.014834                   -0.002925
# 553618                   -0.014834                   -0.002925
#
#         Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                   -0.308324              -0.283797               -0.352025
# 1                   -0.065930               0.525976                0.196145
# 2                   -0.065930               0.525976                0.196145
# 3                   -0.065930               0.525976                0.196145
# 4                   -0.065930               0.525976                0.196145
# ...                       ...                    ...                     ...
# 553614              -0.308324              -0.283797               -0.352025
# 553615              -0.308324              -0.283797               -0.352025
# 553616              -0.308324              -0.283797               -0.352025
# 553617              -0.308324              -0.283797               -0.352025
# 553618              -0.308324              -0.283797               -0.352025
#
#         Fwd Packet Length Std  ...  Fwd Act Data Pkts  Fwd Seg Size Min  \
# 0                   -0.230473  ...          -0.060704         -2.093435
# 1                   -0.230473  ...          -0.035921         -1.513906
# 2                   -0.230473  ...          -0.060704         -1.513906
# 3                   -0.230473  ...          -0.060704         -1.513906
# 4                   -0.230473  ...          -0.060704         -1.513906
# ...                       ...  ...                ...               ...
# 553614              -0.230473  ...          -0.060704          0.804207
# 553615              -0.230473  ...          -0.060704          0.804207
# 553616              -0.230473  ...          -0.060704          0.224679
# 553617              -0.230473  ...          -0.060704          0.804207
# 553618              -0.230473  ...          -0.060704          0.804207
#
#         Active Mean  Active Std  Active Max  Active Min  Idle Mean  Idle Std  \
# 0         -0.701239   -0.096634   -0.709543   -0.694862  -2.185326  0.228321
# 1         -0.700945   -0.097295   -0.709334   -0.694510  -0.920256  1.197414
# 2         -0.701298   -0.097295   -0.709683   -0.694863   0.850843 -0.884519
# 3         -0.701298   -0.097295   -0.709683   -0.694863   0.850843 -0.884519
# 4         -0.701298   -0.097295   -0.709683   -0.694863   0.850843 -0.884519
# ...             ...         ...         ...         ...        ...       ...
# 553614    -0.701298   -0.097295   -0.709683   -0.694863   0.896181 -0.884519
# 553615    -0.701298   -0.097295   -0.709683   -0.694863   0.896351 -0.884519
# 553616    -0.701298   -0.097295   -0.709683   -0.694863   0.896302 -0.884519
# 553617    -0.701298   -0.097295   -0.709683   -0.694863   0.896344 -0.884519
# 553618    -0.701298   -0.097295   -0.709683   -0.694863   0.896184 -0.884519
#
#         Idle Max  Idle Min
# 0      -0.884391 -1.108306
# 1      -0.884389 -1.108306
# 2      -0.884386  0.890400
# 3      -0.884384  0.890400
# 4      -0.884377  0.890400
# ...          ...       ...
# 553614  1.743568  0.915982
# 553615  1.753429  0.916078
# 553616  1.750585  0.916051
# 553617  1.753034  0.916074
# 553618  1.743724  0.915984
#
# [553619 rows x 77 columns]

# %% [markdown]
# ## Menghapus feature yang memiliki low variance

# %%
tres = 1

lv = VarianceThreshold(threshold=tres)
lv.fit_transform(clean_dataset)

filtered_cols = clean_dataset.drop(
    columns=clean_dataset.columns[lv.get_support()].array
).columns.array

lowvariance_dataset = clean_dataset.drop(columns=filtered_cols)
lowvariance_dataset
# Out:
#         Total Fwd Packet  Total Bwd packets  Total Length of Fwd Packet  \
# 0               0.039738          -0.009041                   -0.014834
# 1              -0.027036          -0.002532                   -0.012753
# 2              -0.032600          -0.005787                   -0.013794
# 3              -0.032600          -0.005787                   -0.013794
# 4              -0.032600          -0.005787                   -0.013794
# ...                  ...                ...                         ...
# 553614         -0.015907          -0.009041                   -0.014834
# 553615         -0.015907          -0.009041                   -0.014834
# 553616         -0.027036          -0.009041                   -0.014834
# 553617         -0.015907          -0.009041                   -0.014834
# 553618         -0.015907          -0.009041                   -0.014834
#
#         Total Length of Bwd Packet  Fwd Packet Length Max  \
# 0                        -0.002925              -0.308324
# 1                        -0.002703              -0.065930
# 2                        -0.002814              -0.065930
# 3                        -0.002814              -0.065930
# 4                        -0.002814              -0.065930
# ...                            ...                    ...
# 553614                   -0.002925              -0.308324
# 553615                   -0.002925              -0.308324
# 553616                   -0.002925              -0.308324
# 553617                   -0.002925              -0.308324
# 553618                   -0.002925              -0.308324
#
#         Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# 0                   -0.283797               -0.352025              -0.230473
# 1                    0.525976                0.196145              -0.230473
# 2                    0.525976                0.196145              -0.230473
# 3                    0.525976                0.196145              -0.230473
# 4                    0.525976                0.196145              -0.230473
# ...                       ...                     ...                    ...
# 553614              -0.283797               -0.352025              -0.230473
# 553615              -0.283797               -0.352025              -0.230473
# 553616              -0.283797               -0.352025              -0.230473
# 553617              -0.283797               -0.352025              -0.230473
# 553618              -0.283797               -0.352025              -0.230473
#
#         Bwd Packet Length Max  Bwd Packet Length Mean  ...  \
# 0                   -0.317733               -0.347369  ...
# 1                   -0.146746                0.126632  ...
# 2                   -0.146746                0.126632  ...
# 3                   -0.146746                0.126632  ...
# 4                   -0.146746                0.126632  ...
# ...                       ...                     ...  ...
# 553614              -0.317733               -0.347369  ...
# 553615              -0.317733               -0.347369  ...
# 553616              -0.317733               -0.347369  ...
# 553617              -0.317733               -0.347369  ...
# 553618              -0.317733               -0.347369  ...
#
#         Fwd Segment Size Avg  Bwd Segment Size Avg  Bwd Packet/Bulk Avg  \
# 0                  -0.352025             -0.347369            -0.014252
# 1                   0.196145              0.126632            -0.014252
# 2                   0.196145              0.126632            -0.014252
# 3                   0.196145              0.126632            -0.014252
# 4                   0.196145              0.126632            -0.014252
# ...                      ...                   ...                  ...
# 553614             -0.352025             -0.347369            -0.014252
# 553615             -0.352025             -0.347369            -0.014252
# 553616             -0.352025             -0.347369            -0.014252
# 553617             -0.352025             -0.347369            -0.014252
# 553618             -0.352025             -0.347369            -0.014252
#
#         Subflow Fwd Bytes  FWD Init Win Bytes  Active Mean  Active Std  \
# 0               -0.303802           -1.164520    -0.701239   -0.096634
# 1                0.040964           -1.164520    -0.700945   -0.097295
# 2                0.040964           -1.164520    -0.701298   -0.097295
# 3                0.040964           -1.164520    -0.701298   -0.097295
# 4                0.040964           -1.164520    -0.701298   -0.097295
# ...                   ...                 ...          ...         ...
# 553614          -0.303802            0.871247    -0.701298   -0.097295
# 553615          -0.303802            0.871247    -0.701298   -0.097295
# 553616          -0.303802           -1.131543    -0.701298   -0.097295
# 553617          -0.303802            0.871247    -0.701298   -0.097295
# 553618          -0.303802            0.871247    -0.701298   -0.097295
#
#         Active Max  Idle Mean  Idle Min
# 0        -0.709543  -2.185326 -1.108306
# 1        -0.709334  -0.920256 -1.108306
# 2        -0.709683   0.850843  0.890400
# 3        -0.709683   0.850843  0.890400
# 4        -0.709683   0.850843  0.890400
# ...            ...        ...       ...
# 553614   -0.709683   0.896181  0.915982
# 553615   -0.709683   0.896351  0.916078
# 553616   -0.709683   0.896302  0.916051
# 553617   -0.709683   0.896344  0.916074
# 553618   -0.709683   0.896184  0.915984
#
# [553619 rows x 37 columns]

# %%
lowvariance_dataset["Label"] = dataset["Label"].astype('category').cat.codes
lowvariance_dataset["Label"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 553614    1
# 553615    1
# 553616    1
# 553617    1
# 553618    1
# Name: Label, Length: 553619, dtype: int8

# %% [markdown]
# ## Cari korelasi antara fitur dengan target

# %%
plt.figure(figsize=(12,10))
cor = lowvariance_dataset.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Blues)
plt.show()

# %%
cor_target = abs(cor["Label"])
cor_target
# Out:
# Total Fwd Packet              0.007082
# Total Bwd packets             0.006205
# Total Length of Fwd Packet    0.010601
# Total Length of Bwd Packet    0.002905
# Fwd Packet Length Max         0.295091
# Fwd Packet Length Min         0.292075
# Fwd Packet Length Mean        0.349191
# Fwd Packet Length Std         0.218059
# Bwd Packet Length Max         0.237541
# Bwd Packet Length Mean        0.318564
# Flow IAT Min                  0.026490
# Fwd IAT Total                 0.120745
# Fwd IAT Mean                  0.078448
# Fwd IAT Std                   0.015052
# Fwd IAT Min                   0.104990
# Bwd IAT Std                   0.105699
# Fwd PSH Flags                 0.164358
# Fwd URG Flags                 0.001839
# Bwd Header Length             0.004313
# Fwd Packets/s                 0.034415
# Packet Length Max             0.284469
# Packet Length Std             0.260982
# SYN Flag Count                0.032026
# RST Flag Count                0.043208
# ACK Flag Count                0.005459
# CWR Flag Count                0.008715
# Average Packet Size           0.408521
# Fwd Segment Size Avg          0.349191
# Bwd Segment Size Avg          0.318564
# Bwd Packet/Bulk Avg           0.008291
# Subflow Fwd Bytes             0.304991
# FWD Init Win Bytes            0.836239
# Active Mean                   0.540576
# Active Std                    0.074815
# Active Max                    0.524131
# Idle Mean                     0.280618
# Idle Min                      0.375665
# Label                         1.000000
# Name: Label, dtype: float64

# %%
relevant_features = cor_target[cor_target>0.2]
relevant_features
# Out:
# Fwd Packet Length Max     0.295091
# Fwd Packet Length Min     0.292075
# Fwd Packet Length Mean    0.349191
# Fwd Packet Length Std     0.218059
# Bwd Packet Length Max     0.237541
# Bwd Packet Length Mean    0.318564
# Packet Length Max         0.284469
# Packet Length Std         0.260982
# Average Packet Size       0.408521
# Fwd Segment Size Avg      0.349191
# Bwd Segment Size Avg      0.318564
# Subflow Fwd Bytes         0.304991
# FWD Init Win Bytes        0.836239
# Active Mean               0.540576
# Active Max                0.524131
# Idle Mean                 0.280618
# Idle Min                  0.375665
# Label                     1.000000
# Name: Label, dtype: float64

# %% [markdown]
# ## Hasil lowvariance filter + pearson correlation filter

# %%
all_feature = set(dataset.columns)
rel_feature = set(relevant_features.index)
removed_feature = list(all_feature - rel_feature)
removed_feature

lowvariance_correlationfilter_dataset = dataset.drop(columns=removed_feature)
lowvariance_correlationfilter_dataset
# Out:
#         Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                   -0.308324              -0.283797               -0.352025
# 1                   -0.065930               0.525976                0.196145
# 2                   -0.065930               0.525976                0.196145
# 3                   -0.065930               0.525976                0.196145
# 4                   -0.065930               0.525976                0.196145
# ...                       ...                    ...                     ...
# 553614              -0.308324              -0.283797               -0.352025
# 553615              -0.308324              -0.283797               -0.352025
# 553616              -0.308324              -0.283797               -0.352025
# 553617              -0.308324              -0.283797               -0.352025
# 553618              -0.308324              -0.283797               -0.352025
#
#         Fwd Packet Length Std  Bwd Packet Length Max  Bwd Packet Length Mean  \
# 0                   -0.230473              -0.317733               -0.347369
# 1                   -0.230473              -0.146746                0.126632
# 2                   -0.230473              -0.146746                0.126632
# 3                   -0.230473              -0.146746                0.126632
# 4                   -0.230473              -0.146746                0.126632
# ...                       ...                    ...                     ...
# 553614              -0.230473              -0.317733               -0.347369
# 553615              -0.230473              -0.317733               -0.347369
# 553616              -0.230473              -0.317733               -0.347369
# 553617              -0.230473              -0.317733               -0.347369
# 553618              -0.230473              -0.317733               -0.347369
#
#         Packet Length Max  Packet Length Std  Average Packet Size  \
# 0               -0.358921           -0.30419            -0.419259
# 1               -0.197420           -0.30419             0.130799
# 2               -0.197420           -0.30419             0.240810
# 3               -0.197420           -0.30419             0.240810
# 4               -0.197420           -0.30419             0.240810
# ...                   ...                ...                  ...
# 553614          -0.358921           -0.30419            -0.419259
# 553615          -0.358921           -0.30419            -0.419259
# 553616          -0.358921           -0.30419            -0.419259
# 553617          -0.358921           -0.30419            -0.419259
# 553618          -0.358921           -0.30419            -0.419259
#
#         Fwd Segment Size Avg  Bwd Segment Size Avg  Subflow Fwd Bytes  \
# 0                  -0.352025             -0.347369          -0.303802
# 1                   0.196145              0.126632           0.040964
# 2                   0.196145              0.126632           0.040964
# 3                   0.196145              0.126632           0.040964
# 4                   0.196145              0.126632           0.040964
# ...                      ...                   ...                ...
# 553614             -0.352025             -0.347369          -0.303802
# 553615             -0.352025             -0.347369          -0.303802
# 553616             -0.352025             -0.347369          -0.303802
# 553617             -0.352025             -0.347369          -0.303802
# 553618             -0.352025             -0.347369          -0.303802
#
#         FWD Init Win Bytes  Active Mean  Active Max  Idle Mean  Idle Min  \
# 0                -1.164520    -0.701239   -0.709543  -2.185326 -1.108306
# 1                -1.164520    -0.700945   -0.709334  -0.920256 -1.108306
# 2                -1.164520    -0.701298   -0.709683   0.850843  0.890400
# 3                -1.164520    -0.701298   -0.709683   0.850843  0.890400
# 4                -1.164520    -0.701298   -0.709683   0.850843  0.890400
# ...                    ...          ...         ...        ...       ...
# 553614            0.871247    -0.701298   -0.709683   0.896181  0.915982
# 553615            0.871247    -0.701298   -0.709683   0.896351  0.916078
# 553616           -1.131543    -0.701298   -0.709683   0.896302  0.916051
# 553617            0.871247    -0.701298   -0.709683   0.896344  0.916074
# 553618            0.871247    -0.701298   -0.709683   0.896184  0.915984
#
#             Label
# 0          Benign
# 1          Benign
# 2          Benign
# 3          Benign
# 4          Benign
# ...           ...
# 553614  Malicious
# 553615  Malicious
# 553616  Malicious
# 553617  Malicious
# 553618  Malicious
#
# [553619 rows x 18 columns]

# %%
lowvariance_correlationfilter_dataset.to_csv("/media/kmdr7/Seagate/DATASETS/IOT-23-CIC/Dataset/4-LVCF-3-ZScore-2-Zero.csv", index=False)
