# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA

# %%
dataset = pd.read_csv("/media/kmdr7/Seagate/DATASETS/IOT-23-CIC/Dataset/3-ZScore-2-Mean.csv")
clean_dataset = dataset.drop(columns=["Label"])
clean_dataset
# Out:
#         Protocol  Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0      -1.713649       3.396582          0.039738          -0.009041
# 1       1.876708       1.760380         -0.027036          -0.002532
# 2       1.876708      -0.575959         -0.032600          -0.005787
# 3       1.876708      -0.575129         -0.032600          -0.005787
# 4       1.876708      -0.575557         -0.032600          -0.005787
# ...          ...            ...               ...                ...
# 553614 -0.446464      -0.314008         -0.015907          -0.009041
# 553615 -0.446464      -0.312539         -0.015907          -0.009041
# 553616 -0.446464      -0.574535         -0.027036          -0.009041
# 553617 -0.446464      -0.312284         -0.015907          -0.009041
# 553618 -0.446464      -0.312686         -0.015907          -0.009041
#
#         Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                        -0.014834                   -0.002925
# ...

# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
pca = PCA(0.95)
pca_dataset = pd.DataFrame(pca.fit_transform(clean_dataset))
pca_dataset["Label"] = dataset["Label"]
pca_dataset
# Out:
#                0          1         2         3         4         5         6  \
# 0      -2.229607   3.764813 -0.117099  0.275217  0.257315 -0.023695 -1.839116
# 1      -1.696597  14.356816 -1.255595  4.843810 -1.180270 -0.597340  7.199826
# 2       1.818834  -1.482652 -0.253659  2.615985  0.514076 -0.160817  0.296755
# 3       1.816007  -1.479338 -0.253572  2.612553  0.513126 -0.160740  0.300288
# 4       1.816672  -1.480547 -0.253548  2.613003  0.513112 -0.160618  0.299000
# ...          ...        ...       ...       ...       ...       ...       ...
# 553614 -0.534876  -1.429484 -0.003262  1.170015 -0.352479  0.191862 -0.086043
# 553615 -0.533816  -1.426977 -0.003618  1.172094 -0.352082  0.191591 -0.082990
# 553616 -0.011860  -1.890782 -0.066297  1.752588 -0.283639  0.184916 -0.354259
# 553617 -0.533985  -1.426690 -0.003625  1.172086 -0.351961  0.191492 -0.082089
# 553618 -0.535380  -1.427843 -0.003359  1.170357 -0.351906  0.191405 -0.081767
#
# ...

# %%
pca_dataset.to_csv("/media/kmdr7/Seagate/DATASETS/IOT-23-CIC/Dataset/4-PCA-3-ZScore-2-Mean.csv", index=False)
